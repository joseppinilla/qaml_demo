# %% [markdown]
# # Quantum-Assisted RBM training on the BAS Dataset for Reconstruction
# This is an example on quantum-assisted training of an RBM on the BAS(4,4)
# dataset.
# Developed by: Jose Pinilla

# %%
# Required packages
import qaml
import torch
torch.manual_seed(0) # For deterministic weights

import matplotlib.pyplot as plt
import torchvision.transforms as torch_transforms

# %%
################################# Hyperparameters ##############################
M,N = SHAPE = (4,4)
DATA_SIZE = N*M
HIDDEN_SIZE = 16
EPOCHS = 600
SAMPLES = 1000
BATCH_SIZE = 500
# Stochastic Gradient Descent
learning_rate = 0.1
weight_decay = 1e-4
momentum = 0.5

# %%
#################################### Input Data ################################
train_dataset = qaml.datasets.BAS(*SHAPE,transform=torch_transforms.ToTensor())
train_sampler = torch.utils.data.RandomSampler(train_dataset,replacement=True,
                                               num_samples=SAMPLES)
train_loader = torch.utils.data.DataLoader(train_dataset,sampler=train_sampler,
                                           batch_size=BATCH_SIZE)

# PLot all data
fig,axs = plt.subplots(6,5)
for ax,(img,label) in zip(axs.flat,train_dataset):
    ax.matshow(img.view(*SHAPE),vmin=0,vmax=1); ax.axis('off')
plt.tight_layout()

# %%
################################# Model Definition #############################
# Specify model with dimensions
rbm = qaml.nn.RBM(DATA_SIZE,HIDDEN_SIZE)

# Initialize biases
torch.nn.init.constant_(rbm.b,0.5)
torch.nn.init.zeros_(rbm.c)
torch.nn.init.uniform_(rbm.W,-0.5,0.5)

# Set up optimizers
optimizer = torch.optim.SGD(rbm.parameters(), lr=learning_rate,
                            weight_decay=weight_decay,momentum=momentum)

# Set up training mechanisms
beta = 2.5
solver_name = "Advantage_system1.1"
qa_sampler = qaml.sampler.QASampler(rbm,solver=solver_name,beta=beta)

# Loss and autograd
CD = qaml.autograd.SampleBasedConstrastiveDivergence()

# %%
################################## Model Training ##############################
# Set the model to training mode
rbm.train()
err_log = []
b_log = [rbm.b.detach().clone().numpy()]
c_log = [rbm.c.detach().clone().numpy()]
W_log = [rbm.W.detach().clone().numpy().flatten()]
for t in range(EPOCHS):
    epoch_error = torch.Tensor([0.])

    for img_batch, labels_batch in train_loader:
        input_data = img_batch.flatten(1)

        # Positive Phase
        v0, prob_h0 = input_data, rbm(input_data)
        # Negative Phase
        vk, prob_hk = qa_sampler(BATCH_SIZE,auto_scale=False)

        # Reconstruction error from Contrastive Divergence
        err = CD.apply((v0,prob_h0), (vk,prob_hk), *rbm.parameters())

        # Do not accumulate gradients
        optimizer.zero_grad()

        # Compute gradients
        err.backward()

        # Update parameters
        optimizer.step()

        #Accumulate error for this epoch
        epoch_error  += err

    # Error Log
    b_log.append(rbm.b.detach().clone().numpy())
    c_log.append(rbm.c.detach().clone().numpy())
    W_log.append(rbm.W.detach().clone().numpy().flatten())
    err_log.append(epoch_error.item())
    print(f"Epoch {t} Reconstruction Error = {epoch_error.item()}")

# Set the model to evaluation mode
# rbm.eval()
# Out:
# Epoch 0 Reconstruction Error = 7.159999847412109
# Epoch 1 Reconstruction Error = 4.823999881744385
# Epoch 2 Reconstruction Error = 2.644000291824341
# Epoch 3 Reconstruction Error = 2.251999855041504
# Epoch 4 Reconstruction Error = 1.8980002403259277
# Epoch 5 Reconstruction Error = 1.809999942779541
# Epoch 6 Reconstruction Error = 1.8280000686645508
# Epoch 7 Reconstruction Error = 1.4839999675750732
# Epoch 8 Reconstruction Error = 1.8959999084472656
# Epoch 9 Reconstruction Error = 1.9719998836517334
# Epoch 10 Reconstruction Error = 1.6699999570846558
# Epoch 11 Reconstruction Error = 1.9059998989105225
# Epoch 12 Reconstruction Error = 1.8319998979568481
# Epoch 13 Reconstruction Error = 1.1700003147125244
# Epoch 14 Reconstruction Error = 1.657999873161316
# Epoch 15 Reconstruction Error = 1.5040000677108765
# Epoch 16 Reconstruction Error = 1.587999939918518
# Epoch 17 Reconstruction Error = 1.587999939918518
# Epoch 18 Reconstruction Error = 1.309999942779541
# Epoch 19 Reconstruction Error = 2.0320005416870117
# Epoch 20 Reconstruction Error = 1.4259999990463257
# Epoch 21 Reconstruction Error = 1.5799999237060547
# Epoch 22 Reconstruction Error = 1.5359998941421509
# Epoch 23 Reconstruction Error = 1.506000280380249
# Epoch 24 Reconstruction Error = 1.4140000343322754
# Epoch 25 Reconstruction Error = 1.775999903678894
# Epoch 26 Reconstruction Error = 1.7300001382827759
# Epoch 27 Reconstruction Error = 1.6719999313354492
# Epoch 28 Reconstruction Error = 1.6120002269744873
# Epoch 29 Reconstruction Error = 1.7459999322891235
# Epoch 30 Reconstruction Error = 2.0799999237060547
# Epoch 31 Reconstruction Error = 1.8220000267028809
# Epoch 32 Reconstruction Error = 1.2960002422332764
# Epoch 33 Reconstruction Error = 1.5420000553131104
# Epoch 34 Reconstruction Error = 1.656000018119812
# Epoch 35 Reconstruction Error = 1.7020001411437988
# Epoch 36 Reconstruction Error = 1.6060000658035278
# Epoch 37 Reconstruction Error = 1.9739999771118164
# Epoch 38 Reconstruction Error = 1.2140001058578491
# Epoch 39 Reconstruction Error = 1.8740001916885376
# Epoch 40 Reconstruction Error = 1.7319998741149902
# Epoch 41 Reconstruction Error = 1.5260000228881836
# Epoch 42 Reconstruction Error = 1.7699999809265137
# Epoch 43 Reconstruction Error = 1.126000165939331
# Epoch 44 Reconstruction Error = 1.6560001373291016
# Epoch 45 Reconstruction Error = 1.5579997301101685
# Epoch 46 Reconstruction Error = 1.6440000534057617
# Epoch 47 Reconstruction Error = 1.752000093460083
# Epoch 48 Reconstruction Error = 1.9660000801086426
# Epoch 49 Reconstruction Error = 1.9260001182556152
# Epoch 50 Reconstruction Error = 1.7019996643066406
# Epoch 51 Reconstruction Error = 1.8099998235702515
# Epoch 52 Reconstruction Error = 1.6160001754760742
# Epoch 53 Reconstruction Error = 2.114000082015991
# Epoch 54 Reconstruction Error = 1.5940001010894775
# Epoch 55 Reconstruction Error = 1.3380000591278076
# Epoch 56 Reconstruction Error = 1.557999849319458
# Epoch 57 Reconstruction Error = 1.496000051498413
# Epoch 58 Reconstruction Error = 1.628000020980835
# Epoch 59 Reconstruction Error = 1.953999638557434
# Epoch 60 Reconstruction Error = 1.7320001125335693
# Epoch 61 Reconstruction Error = 1.6539998054504395
# Epoch 62 Reconstruction Error = 1.4600000381469727
# Epoch 63 Reconstruction Error = 1.3559999465942383
# Epoch 64 Reconstruction Error = 1.4660000801086426
# Epoch 65 Reconstruction Error = 1.8839998245239258
# Epoch 66 Reconstruction Error = 2.128000259399414
# Epoch 67 Reconstruction Error = 1.6939997673034668
# Epoch 68 Reconstruction Error = 1.6540000438690186
# Epoch 69 Reconstruction Error = 1.6080000400543213
# Epoch 70 Reconstruction Error = 1.4679999351501465
# Epoch 71 Reconstruction Error = 2.254000186920166
# Epoch 72 Reconstruction Error = 1.5520000457763672
# Epoch 73 Reconstruction Error = 1.8600002527236938
# Epoch 74 Reconstruction Error = 1.6239999532699585
# Epoch 75 Reconstruction Error = 1.8540000915527344
# Epoch 76 Reconstruction Error = 1.3599998950958252
# Epoch 77 Reconstruction Error = 1.3839999437332153
# Epoch 78 Reconstruction Error = 1.5820000171661377
# Epoch 79 Reconstruction Error = 1.784000039100647
# Epoch 80 Reconstruction Error = 1.5239999294281006
# Epoch 81 Reconstruction Error = 1.4219999313354492
# Epoch 82 Reconstruction Error = 1.4200000762939453
# Epoch 83 Reconstruction Error = 1.8739999532699585
# Epoch 84 Reconstruction Error = 1.8959999084472656
# Epoch 85 Reconstruction Error = 1.7740001678466797
# Epoch 86 Reconstruction Error = 1.6419999599456787
# Epoch 87 Reconstruction Error = 1.7440000772476196
# Epoch 88 Reconstruction Error = 1.628000020980835
# Epoch 89 Reconstruction Error = 1.813999891281128
# Epoch 90 Reconstruction Error = 1.8840000629425049
# Epoch 91 Reconstruction Error = 1.6119998693466187
# Epoch 92 Reconstruction Error = 1.4799997806549072
# Epoch 93 Reconstruction Error = 1.565999984741211
# Epoch 94 Reconstruction Error = 1.5039998292922974
# Epoch 95 Reconstruction Error = 1.4539999961853027
# Epoch 96 Reconstruction Error = 1.8739999532699585
# Epoch 97 Reconstruction Error = 1.4540001153945923
# Epoch 98 Reconstruction Error = 1.685999870300293
# Epoch 99 Reconstruction Error = 1.9520001411437988
# Epoch 100 Reconstruction Error = 1.652000069618225
# Epoch 101 Reconstruction Error = 1.1739999055862427
# Epoch 102 Reconstruction Error = 1.1959998607635498
# Epoch 103 Reconstruction Error = 1.3279998302459717
# Epoch 104 Reconstruction Error = 1.5720000267028809
# Epoch 105 Reconstruction Error = 1.6980003118515015
# Epoch 106 Reconstruction Error = 1.7599999904632568
# Epoch 107 Reconstruction Error = 1.6500000953674316
# Epoch 108 Reconstruction Error = 2.169999837875366
# Epoch 109 Reconstruction Error = 1.5580002069473267
# Epoch 110 Reconstruction Error = 1.434000015258789
# Epoch 111 Reconstruction Error = 1.75600004196167
# Epoch 112 Reconstruction Error = 1.6679999828338623
# Epoch 113 Reconstruction Error = 1.6360000371932983
# Epoch 114 Reconstruction Error = 2.434000015258789
# Epoch 115 Reconstruction Error = 1.502000093460083
# Epoch 116 Reconstruction Error = 2.009999990463257
# Epoch 117 Reconstruction Error = 1.6660001277923584
# Epoch 118 Reconstruction Error = 1.4140002727508545
# Epoch 119 Reconstruction Error = 1.6680001020431519
# Epoch 120 Reconstruction Error = 1.9300000667572021
# Epoch 121 Reconstruction Error = 1.5880002975463867
# Epoch 122 Reconstruction Error = 1.6780000925064087
# Epoch 123 Reconstruction Error = 1.4119999408721924
# Epoch 124 Reconstruction Error = 1.837999939918518
# Epoch 125 Reconstruction Error = 1.6340000629425049
# Epoch 126 Reconstruction Error = 1.5920000076293945
# Epoch 127 Reconstruction Error = 2.130000114440918
# Epoch 128 Reconstruction Error = 1.6699999570846558
# Epoch 129 Reconstruction Error = 1.974000096321106
# Epoch 130 Reconstruction Error = 1.9480000734329224
# Epoch 131 Reconstruction Error = 1.50600004196167
# Epoch 132 Reconstruction Error = 1.6140000820159912
# Epoch 133 Reconstruction Error = 1.4900001287460327
# Epoch 134 Reconstruction Error = 1.805999994277954
# Epoch 135 Reconstruction Error = 1.5619999170303345
# Epoch 136 Reconstruction Error = 2.124000072479248
# Epoch 137 Reconstruction Error = 2.008000135421753
# Epoch 138 Reconstruction Error = 1.741999864578247
# Epoch 139 Reconstruction Error = 1.3199999332427979
# Epoch 140 Reconstruction Error = 1.434000015258789
# Epoch 141 Reconstruction Error = 1.4279999732971191
# Epoch 142 Reconstruction Error = 1.6540000438690186
# Epoch 143 Reconstruction Error = 1.6080000400543213
# Epoch 144 Reconstruction Error = 2.2160000801086426
# Epoch 145 Reconstruction Error = 1.4519997835159302
# Epoch 146 Reconstruction Error = 1.5399999618530273
# Epoch 147 Reconstruction Error = 1.564000129699707
# Epoch 148 Reconstruction Error = 1.6400001049041748
# Epoch 149 Reconstruction Error = 1.9260001182556152
# Epoch 150 Reconstruction Error = 1.506000280380249
# Epoch 151 Reconstruction Error = 1.741999864578247
# Epoch 152 Reconstruction Error = 1.419999599456787
# Epoch 153 Reconstruction Error = 1.3899997472763062
# Epoch 154 Reconstruction Error = 1.4579999446868896
# Epoch 155 Reconstruction Error = 1.5320000648498535
# Epoch 156 Reconstruction Error = 1.3939999341964722
# Epoch 157 Reconstruction Error = 1.946000099182129
# Epoch 158 Reconstruction Error = 2.2340002059936523
# Epoch 159 Reconstruction Error = 1.684000015258789
# Epoch 160 Reconstruction Error = 1.4399998188018799
# Epoch 161 Reconstruction Error = 1.504000186920166
# Epoch 162 Reconstruction Error = 1.9119999408721924
# Epoch 163 Reconstruction Error = 1.497999906539917
# Epoch 164 Reconstruction Error = 1.75600004196167
# Epoch 165 Reconstruction Error = 1.371999979019165
# Epoch 166 Reconstruction Error = 2.072000026702881
# Epoch 167 Reconstruction Error = 1.690000295639038
# Epoch 168 Reconstruction Error = 1.623999834060669
# Epoch 169 Reconstruction Error = 1.6319999694824219
# Epoch 170 Reconstruction Error = 1.722000002861023
# Epoch 171 Reconstruction Error = 1.2899999618530273
# Epoch 172 Reconstruction Error = 1.746000051498413
# Epoch 173 Reconstruction Error = 1.9700000286102295
# Epoch 174 Reconstruction Error = 2.047999858856201
# Epoch 175 Reconstruction Error = 1.2760000228881836
# Epoch 176 Reconstruction Error = 1.8060001134872437
# Epoch 177 Reconstruction Error = 1.937999963760376
# Epoch 178 Reconstruction Error = 1.6540000438690186
# Epoch 179 Reconstruction Error = 1.5740001201629639
# Epoch 180 Reconstruction Error = 1.290000081062317
# Epoch 181 Reconstruction Error = 2.3940000534057617
# Epoch 182 Reconstruction Error = 1.4220001697540283
# Epoch 183 Reconstruction Error = 1.3420000076293945
# Epoch 184 Reconstruction Error = 1.7620000839233398
# Epoch 185 Reconstruction Error = 1.5360000133514404
# Epoch 186 Reconstruction Error = 1.5480002164840698
# Epoch 187 Reconstruction Error = 1.6520001888275146
# Epoch 188 Reconstruction Error = 1.1560001373291016
# Epoch 189 Reconstruction Error = 1.5099999904632568
# Epoch 190 Reconstruction Error = 1.5319998264312744
# Epoch 191 Reconstruction Error = 1.75
# Epoch 192 Reconstruction Error = 1.6480000019073486
# Epoch 193 Reconstruction Error = 1.320000171661377
# Epoch 194 Reconstruction Error = 1.7780001163482666
# Epoch 195 Reconstruction Error = 1.6979999542236328
# Epoch 196 Reconstruction Error = 2.3400001525878906
# Epoch 197 Reconstruction Error = 2.2760000228881836
# Epoch 198 Reconstruction Error = 1.628000020980835
# Epoch 199 Reconstruction Error = 2.1560001373291016
# Epoch 200 Reconstruction Error = 1.931999921798706
# Epoch 201 Reconstruction Error = 1.5540000200271606
# Epoch 202 Reconstruction Error = 2.131999969482422
# Epoch 203 Reconstruction Error = 2.257999897003174
# Epoch 204 Reconstruction Error = 1.6840001344680786
# Epoch 205 Reconstruction Error = 1.8019999265670776
# Epoch 206 Reconstruction Error = 1.636000156402588
# Epoch 207 Reconstruction Error = 1.8779999017715454
# Epoch 208 Reconstruction Error = 1.9279999732971191
# Epoch 209 Reconstruction Error = 1.96399986743927
# Epoch 210 Reconstruction Error = 2.0260000228881836
# Epoch 211 Reconstruction Error = 2.0460000038146973
# Epoch 212 Reconstruction Error = 1.1759999990463257
# Epoch 213 Reconstruction Error = 1.3960001468658447
# Epoch 214 Reconstruction Error = 1.4720001220703125
# Epoch 215 Reconstruction Error = 1.8300000429153442
# Epoch 216 Reconstruction Error = 2.0759999752044678
# Epoch 217 Reconstruction Error = 1.7039999961853027
# Epoch 218 Reconstruction Error = 1.6680001020431519
# Epoch 219 Reconstruction Error = 2.2139999866485596
# Epoch 220 Reconstruction Error = 1.4040000438690186
# Epoch 221 Reconstruction Error = 1.5799999237060547
# Epoch 222 Reconstruction Error = 1.3680000305175781
# Epoch 223 Reconstruction Error = 1.5959999561309814
# Epoch 224 Reconstruction Error = 1.8960001468658447
# Epoch 225 Reconstruction Error = 1.493999719619751
# Epoch 226 Reconstruction Error = 1.3680001497268677
# Epoch 227 Reconstruction Error = 2.0939998626708984
# Epoch 228 Reconstruction Error = 1.8360002040863037
# Epoch 229 Reconstruction Error = 1.9220001697540283
# Epoch 230 Reconstruction Error = 2.3460001945495605
# Epoch 231 Reconstruction Error = 1.784000277519226
# Epoch 232 Reconstruction Error = 1.497999906539917
# Epoch 233 Reconstruction Error = 1.7960000038146973
# Epoch 234 Reconstruction Error = 2.2900002002716064
# Epoch 235 Reconstruction Error = 1.7400000095367432
# Epoch 236 Reconstruction Error = 1.9099998474121094
# Epoch 237 Reconstruction Error = 1.8580000400543213
# Epoch 238 Reconstruction Error = 1.7619998455047607
# Epoch 239 Reconstruction Error = 1.4119999408721924
# Epoch 240 Reconstruction Error = 1.7279999256134033
# Epoch 241 Reconstruction Error = 1.4680001735687256
# Epoch 242 Reconstruction Error = 1.8040001392364502
# Epoch 243 Reconstruction Error = 1.6580002307891846
# Epoch 244 Reconstruction Error = 1.694000244140625
# Epoch 245 Reconstruction Error = 1.6099998950958252
# Epoch 246 Reconstruction Error = 1.803999900817871
# Epoch 247 Reconstruction Error = 1.3799999952316284
# Epoch 248 Reconstruction Error = 1.7419999837875366
# Epoch 249 Reconstruction Error = 2.0199997425079346
# Epoch 250 Reconstruction Error = 1.9760000705718994
# Epoch 251 Reconstruction Error = 1.7699999809265137
# Epoch 252 Reconstruction Error = 1.995999813079834
# Epoch 253 Reconstruction Error = 1.690000057220459
# Epoch 254 Reconstruction Error = 1.5660001039505005
# Epoch 255 Reconstruction Error = 1.446000099182129
# Epoch 256 Reconstruction Error = 1.5139999389648438
# Epoch 257 Reconstruction Error = 1.9520001411437988
# Epoch 258 Reconstruction Error = 1.9160000085830688
# Epoch 259 Reconstruction Error = 2.361999988555908
# Epoch 260 Reconstruction Error = 1.375999927520752
# Epoch 261 Reconstruction Error = 1.43399977684021
# Epoch 262 Reconstruction Error = 1.5040000677108765
# Epoch 263 Reconstruction Error = 1.6660001277923584
# Epoch 264 Reconstruction Error = 1.4500000476837158
# Epoch 265 Reconstruction Error = 1.9899998903274536
# Epoch 266 Reconstruction Error = 1.6460000276565552
# Epoch 267 Reconstruction Error = 1.4760000705718994
# Epoch 268 Reconstruction Error = 2.3480000495910645
# Epoch 269 Reconstruction Error = 2.140000343322754
# Epoch 270 Reconstruction Error = 2.125999927520752
# Epoch 271 Reconstruction Error = 1.1519999504089355
# Epoch 272 Reconstruction Error = 1.8980000019073486
# Epoch 273 Reconstruction Error = 2.055999994277954
# Epoch 274 Reconstruction Error = 1.8919999599456787
# Epoch 275 Reconstruction Error = 1.7220001220703125
# Epoch 276 Reconstruction Error = 1.7819998264312744
# Epoch 277 Reconstruction Error = 1.852000117301941
# Epoch 278 Reconstruction Error = 1.934000015258789
# Epoch 279 Reconstruction Error = 2.36799955368042
# Epoch 280 Reconstruction Error = 1.8420000076293945
# Epoch 281 Reconstruction Error = 1.9960001707077026
# Epoch 282 Reconstruction Error = 2.442000150680542
# Epoch 283 Reconstruction Error = 2.111999988555908
# Epoch 284 Reconstruction Error = 1.8019999265670776
# Epoch 285 Reconstruction Error = 1.9539999961853027
# Epoch 286 Reconstruction Error = 1.7919998168945312
# Epoch 287 Reconstruction Error = 1.4819999933242798
# Epoch 288 Reconstruction Error = 2.1540000438690186
# Epoch 289 Reconstruction Error = 2.1080002784729004
# Epoch 290 Reconstruction Error = 1.3999996185302734
# Epoch 291 Reconstruction Error = 1.6440000534057617
# Epoch 292 Reconstruction Error = 2.257999897003174
# Epoch 293 Reconstruction Error = 1.0799999237060547
# Epoch 294 Reconstruction Error = 2.293999671936035
# Epoch 295 Reconstruction Error = 1.3819998502731323
# Epoch 296 Reconstruction Error = 1.8499999046325684
# Epoch 297 Reconstruction Error = 1.9559999704360962
# Epoch 298 Reconstruction Error = 1.968000054359436
# Epoch 299 Reconstruction Error = 2.258000135421753
# Epoch 300 Reconstruction Error = 2.1500000953674316
# Epoch 301 Reconstruction Error = 1.249999761581421
# Epoch 302 Reconstruction Error = 1.565999984741211
# Epoch 303 Reconstruction Error = 1.805999994277954
# Epoch 304 Reconstruction Error = 1.1759999990463257
# Epoch 305 Reconstruction Error = 1.593999981880188
# Epoch 306 Reconstruction Error = 1.5739998817443848
# Epoch 307 Reconstruction Error = 1.7559999227523804
# Epoch 308 Reconstruction Error = 1.7220001220703125
# Epoch 309 Reconstruction Error = 1.8859999179840088
# Epoch 310 Reconstruction Error = 1.8700001239776611
# Epoch 311 Reconstruction Error = 1.3960002660751343
# Epoch 312 Reconstruction Error = 1.9100000858306885
# Epoch 313 Reconstruction Error = 2.12600040435791
# Epoch 314 Reconstruction Error = 1.375999927520752
# Epoch 315 Reconstruction Error = 2.23799991607666
# Epoch 316 Reconstruction Error = 1.3900002241134644
# Epoch 317 Reconstruction Error = 2.173999786376953
# Epoch 318 Reconstruction Error = 2.136000156402588
# Epoch 319 Reconstruction Error = 2.1659998893737793
# Epoch 320 Reconstruction Error = 1.8899998664855957
# Epoch 321 Reconstruction Error = 1.5500000715255737
# Epoch 322 Reconstruction Error = 2.3359999656677246
# Epoch 323 Reconstruction Error = 1.7660000324249268
# Epoch 324 Reconstruction Error = 2.7179999351501465
# Epoch 325 Reconstruction Error = 2.2939999103546143
# Epoch 326 Reconstruction Error = 2.251999855041504
# Epoch 327 Reconstruction Error = 1.4100000858306885
# Epoch 328 Reconstruction Error = 2.2139997482299805
# Epoch 329 Reconstruction Error = 2.2839996814727783
# Epoch 330 Reconstruction Error = 2.0439999103546143
# Epoch 331 Reconstruction Error = 1.9739999771118164
# Epoch 332 Reconstruction Error = 2.3239998817443848
# Epoch 333 Reconstruction Error = 1.7980002164840698
# Epoch 334 Reconstruction Error = 1.3380000591278076
# Epoch 335 Reconstruction Error = 1.2079999446868896
# Epoch 336 Reconstruction Error = 1.6079998016357422
# Epoch 337 Reconstruction Error = 1.7699998617172241
# Epoch 338 Reconstruction Error = 1.7139997482299805
# Epoch 339 Reconstruction Error = 1.226000189781189
# Epoch 340 Reconstruction Error = 1.589999794960022
# Epoch 341 Reconstruction Error = 1.9640001058578491
# Epoch 342 Reconstruction Error = 1.2400001287460327
# Epoch 343 Reconstruction Error = 2.0980005264282227
# Epoch 344 Reconstruction Error = 2.248000144958496
# Epoch 345 Reconstruction Error = 1.936000108718872
# Epoch 346 Reconstruction Error = 1.7179999351501465
# Epoch 347 Reconstruction Error = 1.5799999237060547
# Epoch 348 Reconstruction Error = 1.5640000104904175
# Epoch 349 Reconstruction Error = 2.2280001640319824
# Epoch 350 Reconstruction Error = 1.562000036239624
# Epoch 351 Reconstruction Error = 2.0959997177124023
# Epoch 352 Reconstruction Error = 2.202000141143799
# Epoch 353 Reconstruction Error = 1.4839999675750732
# Epoch 354 Reconstruction Error = 1.9720001220703125
# Epoch 355 Reconstruction Error = 2.1579999923706055
# Epoch 356 Reconstruction Error = 2.5439999103546143
# Epoch 357 Reconstruction Error = 1.878000020980835
# Epoch 358 Reconstruction Error = 1.9380000829696655
# Epoch 359 Reconstruction Error = 2.129999876022339
# Epoch 360 Reconstruction Error = 2.308000087738037
# Epoch 361 Reconstruction Error = 1.380000114440918
# Epoch 362 Reconstruction Error = 1.5700000524520874
# Epoch 363 Reconstruction Error = 1.1320000886917114
# Epoch 364 Reconstruction Error = 2.078000068664551
# Epoch 365 Reconstruction Error = 2.1679999828338623
# Epoch 366 Reconstruction Error = 1.5839998722076416
# Epoch 367 Reconstruction Error = 1.8499999046325684
# Epoch 368 Reconstruction Error = 1.2100000381469727
# Epoch 369 Reconstruction Error = 2.5420000553131104
# Epoch 370 Reconstruction Error = 1.7200000286102295
# Epoch 371 Reconstruction Error = 2.6659998893737793
# Epoch 372 Reconstruction Error = 1.9539998769760132
# Epoch 373 Reconstruction Error = 1.7379997968673706
# Epoch 374 Reconstruction Error = 1.3899998664855957
# Epoch 375 Reconstruction Error = 1.6660001277923584
# Epoch 376 Reconstruction Error = 1.875999927520752
# Epoch 377 Reconstruction Error = 2.4060001373291016
# Epoch 378 Reconstruction Error = 1.746000051498413
# Epoch 379 Reconstruction Error = 1.3859999179840088
# Epoch 380 Reconstruction Error = 2.1579999923706055
# Epoch 381 Reconstruction Error = 1.7719999551773071
# Epoch 382 Reconstruction Error = 1.5439999103546143
# Epoch 383 Reconstruction Error = 2.2220001220703125
# Epoch 384 Reconstruction Error = 1.8239998817443848
# Epoch 385 Reconstruction Error = 1.9279999732971191
# Epoch 386 Reconstruction Error = 2.3540003299713135
# Epoch 387 Reconstruction Error = 1.6119999885559082
# Epoch 388 Reconstruction Error = 1.191999912261963
# Epoch 389 Reconstruction Error = 1.9060001373291016
# Epoch 390 Reconstruction Error = 1.406000018119812
# Epoch 391 Reconstruction Error = 1.8559999465942383
# Epoch 392 Reconstruction Error = 1.8380000591278076
# Epoch 393 Reconstruction Error = 1.3560000658035278
# Epoch 394 Reconstruction Error = 2.308000087738037
# Epoch 395 Reconstruction Error = 2.1539998054504395
# Epoch 396 Reconstruction Error = 2.1519999504089355
# Epoch 397 Reconstruction Error = 1.7100002765655518
# Epoch 398 Reconstruction Error = 1.7719999551773071
# Epoch 399 Reconstruction Error = 1.5820001363754272
# Epoch 400 Reconstruction Error = 1.6060001850128174
# Epoch 401 Reconstruction Error = 2.008000135421753
# Epoch 402 Reconstruction Error = 1.187999963760376
# Epoch 403 Reconstruction Error = 2.2060000896453857
# Epoch 404 Reconstruction Error = 1.6059998273849487
# Epoch 405 Reconstruction Error = 2.109999895095825
# Epoch 406 Reconstruction Error = 2.072000026702881
# Epoch 407 Reconstruction Error = 1.3239998817443848
# Epoch 408 Reconstruction Error = 1.6820000410079956
# Epoch 409 Reconstruction Error = 1.8559999465942383
# Epoch 410 Reconstruction Error = 1.621999979019165
# Epoch 411 Reconstruction Error = 2.0699996948242188
# Epoch 412 Reconstruction Error = 1.8179999589920044
# Epoch 413 Reconstruction Error = 2.0400002002716064
# Epoch 414 Reconstruction Error = 1.1079998016357422
# Epoch 415 Reconstruction Error = 1.7699999809265137
# Epoch 416 Reconstruction Error = 2.0340001583099365
# Epoch 417 Reconstruction Error = 2.254000186920166
# Epoch 418 Reconstruction Error = 2.381999969482422
# Epoch 419 Reconstruction Error = 1.5500000715255737
# Epoch 420 Reconstruction Error = 1.7200000286102295
# Epoch 421 Reconstruction Error = 1.6060000658035278
# Epoch 422 Reconstruction Error = 1.7020001411437988
# Epoch 423 Reconstruction Error = 2.0899996757507324
# Epoch 424 Reconstruction Error = 1.3019999265670776
# Epoch 425 Reconstruction Error = 1.6360000371932983
# Epoch 426 Reconstruction Error = 2.2860000133514404
# Epoch 427 Reconstruction Error = 1.8940001726150513
# Epoch 428 Reconstruction Error = 2.0219998359680176
# Epoch 429 Reconstruction Error = 2.0180001258850098
# Epoch 430 Reconstruction Error = 1.4900001287460327
# Epoch 431 Reconstruction Error = 1.8080002069473267
# Epoch 432 Reconstruction Error = 1.6680001020431519
# Epoch 433 Reconstruction Error = 2.1740002632141113
# Epoch 434 Reconstruction Error = 1.5899999141693115
# Epoch 435 Reconstruction Error = 2.5860002040863037
# Epoch 436 Reconstruction Error = 1.461999773979187
# Epoch 437 Reconstruction Error = 1.7619999647140503
# Epoch 438 Reconstruction Error = 1.5019999742507935
# Epoch 439 Reconstruction Error = 2.142000198364258
# Epoch 440 Reconstruction Error = 1.8939999341964722
# Epoch 441 Reconstruction Error = 1.8980000019073486
# Epoch 442 Reconstruction Error = 1.7960000038146973
# Epoch 443 Reconstruction Error = 2.1440000534057617
# Epoch 444 Reconstruction Error = 1.78600013256073
# Epoch 445 Reconstruction Error = 1.9339998960494995
# Epoch 446 Reconstruction Error = 1.8839999437332153
# Epoch 447 Reconstruction Error = 1.0780000686645508
# Epoch 448 Reconstruction Error = 1.8919999599456787
# Epoch 449 Reconstruction Error = 1.6039998531341553
# Epoch 450 Reconstruction Error = 1.531999945640564
# Epoch 451 Reconstruction Error = 2.5379998683929443
# Epoch 452 Reconstruction Error = 2.198000192642212
# Epoch 453 Reconstruction Error = 1.3980000019073486
# Epoch 454 Reconstruction Error = 1.1939998865127563
# Epoch 455 Reconstruction Error = 1.842000126838684
# Epoch 456 Reconstruction Error = 2.169999837875366
# Epoch 457 Reconstruction Error = 1.3119999170303345
# Epoch 458 Reconstruction Error = 1.6540000438690186
# Epoch 459 Reconstruction Error = 1.3380000591278076
# Epoch 460 Reconstruction Error = 2.169999837875366
# Epoch 461 Reconstruction Error = 2.0160000324249268
# Epoch 462 Reconstruction Error = 2.3460001945495605
# Epoch 463 Reconstruction Error = 1.5099999904632568
# Epoch 464 Reconstruction Error = 1.6600000858306885
# Epoch 465 Reconstruction Error = 1.7899999618530273
# Epoch 466 Reconstruction Error = 1.2660000324249268
# Epoch 467 Reconstruction Error = 2.685999870300293
# Epoch 468 Reconstruction Error = 1.346000075340271
# Epoch 469 Reconstruction Error = 1.215999960899353
# Epoch 470 Reconstruction Error = 1.559999942779541
# Epoch 471 Reconstruction Error = 2.2960000038146973
# Epoch 472 Reconstruction Error = 1.700000286102295
# Epoch 473 Reconstruction Error = 1.8260002136230469
# Epoch 474 Reconstruction Error = 1.902000069618225
# Epoch 475 Reconstruction Error = 1.8359999656677246
# Epoch 476 Reconstruction Error = 2.5439999103546143
# Epoch 477 Reconstruction Error = 2.116000175476074
# Epoch 478 Reconstruction Error = 2.0500001907348633
# Epoch 479 Reconstruction Error = 1.6460001468658447
# Epoch 480 Reconstruction Error = 1.7599998712539673
# Epoch 481 Reconstruction Error = 0.9559999704360962
# Epoch 482 Reconstruction Error = 2.078000068664551
# Epoch 483 Reconstruction Error = 2.25
# Epoch 484 Reconstruction Error = 1.8380000591278076
# Epoch 485 Reconstruction Error = 1.7100002765655518
# Epoch 486 Reconstruction Error = 1.309999942779541
# Epoch 487 Reconstruction Error = 2.386000156402588
# Epoch 488 Reconstruction Error = 1.4240000247955322
# Epoch 489 Reconstruction Error = 2.2940001487731934
# Epoch 490 Reconstruction Error = 1.1339999437332153
# Epoch 491 Reconstruction Error = 2.2839999198913574
# Epoch 492 Reconstruction Error = 1.656000018119812
# Epoch 493 Reconstruction Error = 1.5460000038146973
# Epoch 494 Reconstruction Error = 1.8319998979568481
# Epoch 495 Reconstruction Error = 2.815999984741211
# Epoch 496 Reconstruction Error = 1.6920002698898315
# Epoch 497 Reconstruction Error = 2.065999984741211
# Epoch 498 Reconstruction Error = 1.9019999504089355
# Epoch 499 Reconstruction Error = 1.5520000457763672
# Epoch 500 Reconstruction Error = 2.2760000228881836
# Epoch 501 Reconstruction Error = 1.8480000495910645
# Epoch 502 Reconstruction Error = 2.004000186920166
# Epoch 503 Reconstruction Error = 1.8799998760223389
# Epoch 504 Reconstruction Error = 1.6820001602172852
# Epoch 505 Reconstruction Error = 2.5320000648498535
# Epoch 506 Reconstruction Error = 1.9840000867843628
# Epoch 507 Reconstruction Error = 1.9359997510910034
# Epoch 508 Reconstruction Error = 2.0200002193450928
# Epoch 509 Reconstruction Error = 1.9119999408721924
# Epoch 510 Reconstruction Error = 2.7160000801086426
# Epoch 511 Reconstruction Error = 1.781999945640564
# Epoch 512 Reconstruction Error = 2.378000259399414
# Epoch 513 Reconstruction Error = 1.5140000581741333
# Epoch 514 Reconstruction Error = 1.8060001134872437
# Epoch 515 Reconstruction Error = 2.3799996376037598
# Epoch 516 Reconstruction Error = 1.9660000801086426
# Epoch 517 Reconstruction Error = 1.9260001182556152
# Epoch 518 Reconstruction Error = 2.5480000972747803
# Epoch 519 Reconstruction Error = 1.997999906539917
# Epoch 520 Reconstruction Error = 1.3919999599456787
# Epoch 521 Reconstruction Error = 1.9399996995925903
# Epoch 522 Reconstruction Error = 1.5499999523162842
# Epoch 523 Reconstruction Error = 2.0
# Epoch 524 Reconstruction Error = 1.6619999408721924
# Epoch 525 Reconstruction Error = 1.6440000534057617
# Epoch 526 Reconstruction Error = 1.9739999771118164
# Epoch 527 Reconstruction Error = 2.0799999237060547
# Epoch 528 Reconstruction Error = 2.068000078201294
# Epoch 529 Reconstruction Error = 2.076000213623047
# Epoch 530 Reconstruction Error = 1.4600001573562622
# Epoch 531 Reconstruction Error = 1.9639999866485596
# Epoch 532 Reconstruction Error = 1.7319999933242798
# Epoch 533 Reconstruction Error = 1.3239998817443848
# Epoch 534 Reconstruction Error = 1.1319999694824219
# Epoch 535 Reconstruction Error = 1.0579999685287476
# Epoch 536 Reconstruction Error = 1.75
# Epoch 537 Reconstruction Error = 2.2900002002716064
# Epoch 538 Reconstruction Error = 2.1399998664855957
# Epoch 539 Reconstruction Error = 1.863999843597412
# Epoch 540 Reconstruction Error = 1.906000018119812
# Epoch 541 Reconstruction Error = 1.1420001983642578
# Epoch 542 Reconstruction Error = 2.1080002784729004
# Epoch 543 Reconstruction Error = 1.9700002670288086
# Epoch 544 Reconstruction Error = 2.051999807357788
# Epoch 545 Reconstruction Error = 1.5740001201629639
# Epoch 546 Reconstruction Error = 2.142000198364258
# Epoch 547 Reconstruction Error = 2.558000087738037
# Epoch 548 Reconstruction Error = 1.9800002574920654
# Epoch 549 Reconstruction Error = 2.450000047683716
# Epoch 550 Reconstruction Error = 1.75600004196167
# Epoch 551 Reconstruction Error = 1.628000020980835
# Epoch 552 Reconstruction Error = 1.1080001592636108
# Epoch 553 Reconstruction Error = 1.8279999494552612
# Epoch 554 Reconstruction Error = 1.7979997396469116
# Epoch 555 Reconstruction Error = 1.4120001792907715
# Epoch 556 Reconstruction Error = 1.3199999332427979
# Epoch 557 Reconstruction Error = 1.6879997253417969
# Epoch 558 Reconstruction Error = 1.8320002555847168
# Epoch 559 Reconstruction Error = 1.2940000295639038
# Epoch 560 Reconstruction Error = 2.4179999828338623
# Epoch 561 Reconstruction Error = 2.386000156402588
# Epoch 562 Reconstruction Error = 2.383999824523926
# Epoch 563 Reconstruction Error = 1.6879998445510864
# Epoch 564 Reconstruction Error = 1.874000072479248
# Epoch 565 Reconstruction Error = 2.812000274658203
# Epoch 566 Reconstruction Error = 1.2280000448226929
# Epoch 567 Reconstruction Error = 1.6660001277923584
# Epoch 568 Reconstruction Error = 2.0279998779296875
# Epoch 569 Reconstruction Error = 1.1679997444152832
# Epoch 570 Reconstruction Error = 1.7839999198913574
# Epoch 571 Reconstruction Error = 1.741999626159668
# Epoch 572 Reconstruction Error = 2.1660001277923584
# Epoch 573 Reconstruction Error = 1.5119998455047607
# Epoch 574 Reconstruction Error = 2.0180001258850098
# Epoch 575 Reconstruction Error = 1.3660000562667847
# Epoch 576 Reconstruction Error = 1.7099997997283936
# Epoch 577 Reconstruction Error = 1.1739999055862427
# Epoch 578 Reconstruction Error = 1.5320000648498535
# Epoch 579 Reconstruction Error = 2.3979997634887695
# Epoch 580 Reconstruction Error = 1.9339998960494995
# Epoch 581 Reconstruction Error = 1.96399986743927
# Epoch 582 Reconstruction Error = 2.0960001945495605
# Epoch 583 Reconstruction Error = 1.690000057220459
# Epoch 584 Reconstruction Error = 1.5419999361038208
# Epoch 585 Reconstruction Error = 1.6180000305175781
# Epoch 586 Reconstruction Error = 1.899999737739563
# Epoch 587 Reconstruction Error = 1.847999930381775
# Epoch 588 Reconstruction Error = 1.8040000200271606
# Epoch 589 Reconstruction Error = 2.111999988555908
# Epoch 590 Reconstruction Error = 1.7100000381469727
# Epoch 591 Reconstruction Error = 1.940000057220459
# Epoch 592 Reconstruction Error = 1.534000039100647
# Epoch 593 Reconstruction Error = 1.9160000085830688
# Epoch 594 Reconstruction Error = 1.8199999332427979
# Epoch 595 Reconstruction Error = 1.5859999656677246
# Epoch 596 Reconstruction Error = 2.2140002250671387
# Epoch 597 Reconstruction Error = 2.509999990463257
# Epoch 598 Reconstruction Error = 2.3219997882843018
# Epoch 599 Reconstruction Error = 1.9199999570846558

# %%
########################### Store Model and Logs ##############################
torch.save(rbm,"quantum_rbm.pt")
torch.save(b_log,"quantum_b.pt")
torch.save(c_log,"quantum_c.pt")
torch.save(W_log,"quantum_W.pt")
torch.save(err_log,"quantum_err.pt")
torch.save(dict(qa_sampler.embedding),"embedding.pt")

# %% [raw]
# ########################### Load Model and Logs ###############################
# rbm = torch.load("quantum_rbm.pt")
# b_log = torch.load("quantum_b.pt")
# c_log = torch.load("quantum_c.pt")
# W_log = torch.load("quantum_W.pt")
# err_log = torch.load("quantum_err.pt")
# embedding = torch.load("embedding.pt")
# qa_sampler = qaml.sampler.QASampler(rbm,solver=solver_name,beta=beta,embedding=embedding)

# %%
################################# qBAS Score ###################################
num_samples = 1000 # CLASSICAL
gibbs_sampler = qaml.sampler.GibbsNetworkSampler(rbm)
prob_v,_ = gibbs_sampler(torch.rand(num_samples,DATA_SIZE),k=10)
img_samples = prob_v.view(num_samples,*SHAPE).bernoulli()
# PLot some samples
fig,axs = plt.subplots(4,5)
for ax,img in zip(axs.flat,img_samples):
    ax.matshow(img.view(*SHAPE),vmin=0,vmax=1); ax.axis('off')
plt.tight_layout()
# Get and print score
p,r,score = train_dataset.score(img_samples)
print(f"qBAS : Precision = {p:.02} Recall = {r:.02} Score = {score:.02}")
# Out:
# qBAS : Precision = 0.46 Recall = 0.9 Score = 0.61

# %%
############################## RECONSTRUCTION ##################################
k = 10
count = 0

mask = torch_transforms.functional.erase(torch.ones(1,M,N),1,1,2,2,0).flatten()
for img, label in train_dataset:

    clamped = mask*img.flatten(1)
    prob_hk = rbm.forward(clamped + (1-mask)*0.5)
    prob_vk = rbm.generate(prob_hk).detach()
    for _ in range(k):
        masked = clamped + (1-mask)*prob_vk.data
        prob_hk.data = rbm.forward(masked).data
        prob_vk.data = rbm.generate(prob_hk).data
    recon = (clamped + (1-mask)*prob_vk).bernoulli().view(img.shape)

    if recon.equal(img):
        count+=1
print(f"Dataset Reconstruction: {count/len(train_dataset):.02}")
# Out:
# Dataset Reconstruction: 0.93

# %%
############################ MODEL VISUALIZATION ###############################

# L1 error graph
plt.plot(err_log)
plt.ylabel("Reconstruction Error")
plt.xlabel("Epoch")
plt.savefig("quantum_err_log.pdf")

# Visible bias graph
fig, ax = plt.subplots()
ax.set_prop_cycle('color', list(plt.get_cmap('turbo',DATA_SIZE).colors))
lc_v = ax.plot(b_log)
plt.legend(iter(lc_v),[f'b{i}' for i in range(DATA_SIZE)],ncol=2,bbox_to_anchor=(1,1))
plt.ylabel("Visible Biases")
plt.xlabel("Epoch")
plt.savefig("quantum_b_log.pdf")

# Hidden bias graph
fig, ax = plt.subplots()
ax.set_prop_cycle('color', list(plt.get_cmap('turbo',HIDDEN_SIZE).colors))
lc_h = plt.plot(c_log)
plt.legend(lc_h,[f'c{i}' for i in range(HIDDEN_SIZE)],ncol=2,bbox_to_anchor=(1,1))
plt.ylabel("Hidden Biases")
plt.xlabel("Epoch")
plt.savefig("quantum_c_log.pdf")

# Weights graph
fig, ax = plt.subplots()
ax.set_prop_cycle('color', list(plt.get_cmap('turbo',rbm.V*rbm.H).colors))
lc_w = plt.plot(W_log)
plt.ylabel("Weights")
plt.xlabel("Epoch")
plt.savefig("quantum_W_log.pdf")

# %%
################################## ENERGY ######################################
data_energies = []
for img,label in train_dataset:
    data = img.flatten(1)
    data_energies.append(rbm.free_energy(data).item())

rand_energies = []
rand_data = torch.rand(len(train_dataset)*10,rbm.V)
for img in rand_data:
    rand_energies.append(rbm.free_energy(img.bernoulli()).item())

gibbs_energies = []
gibbs_sampler = qaml.sampler.GibbsNetworkSampler(rbm)
for img,label in train_dataset:
    data = img.flatten(1)
    prob_v,prob_h = gibbs_sampler(data,k=5)
    gibbs_energies.append(rbm.free_energy(prob_v.bernoulli()).item())

qa_energies = []
qa_sampleset = qa_sampler(num_reads=1000,auto_scale=False)
for s_v,s_h in zip(*qa_sampleset):
    qa_energies.append(rbm.free_energy(s_v.detach()).item())

plot_data = [(data_energies,  'Data',    'blue'),
             (rand_energies,  'Random',  'red'),
             (gibbs_energies, 'Gibbs-5', 'green'),
             (qa_energies,    'Quantum', 'orange')]

hist_kwargs = {'ec':'k','lw':2.0,'alpha':0.5,'histtype':'stepfilled','bins':100}
weights = lambda data: [1./len(data) for _ in data]

fig, ax = plt.subplots(figsize=(15,10))
for data,name,color in plot_data:
    ax.hist(data,weights=weights(data),label=name,color=color,**hist_kwargs)

plt.xlabel("Energy")
plt.ylabel("Count/Total")
plt.legend(loc='upper right')
plt.savefig("quantum_energies.pdf")

# %%
################################## VISUALIZE ###################################
plt.matshow(rbm.b.detach().view(*SHAPE))
plt.colorbar()
plt.savefig("quantum_b.pdf")
plt.matshow(rbm.c.detach().view(1,HIDDEN_SIZE))
plt.yticks([])
plt.colorbar()
plt.savefig("quantum_c.pdf")

fig,axs = plt.subplots(HIDDEN_SIZE//4,4)
for i,ax in enumerate(axs.flat):
    weight_matrix = rbm.W[i].detach().view(*SHAPE)
    ms = ax.matshow(weight_matrix)
    ax.axis('off')
fig.subplots_adjust(wspace=0.1, hspace=0.1)
cbar = fig.colorbar(ms, ax=axs.ravel().tolist(), shrink=0.95)
plt.savefig("quantum_weights.pdf")

# %%
########################### Check parameter range ##############################
h_range = qa_sampler.properties['h_range']
J_range = qa_sampler.properties['extended_j_range']
target_ising = qa_sampler.embed_bqm().spin
linear = target_ising.linear.values()
quad = target_ising.quadratic.values()
print(f"Linear range [{min(linear):.2} <> {max(linear):.2}] @ device={h_range}")
print(f"Quadratic range [{min(quad):.2} <> {max(quad):.2}] @ device={J_range}")
# Out:
# Linear range [-0.84 <> 1.1] @ device=[-2.0, 2.0]
# Quadratic range [-1.6 <> 0.46] @ device=[-2.0, 1.0]
