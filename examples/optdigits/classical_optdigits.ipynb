# %% [markdown]
# # Classical RBM training on the OptDigits Dataset for reconstruction and classification
# This is an example on classical Gibbs training of an RBM on the OptDigits
# dataset.
# Developed by: Jose Pinilla

# %%
# Required packages
import qaml
import torch
torch.manual_seed(0) # For deterministic weights

import torch.nn.functional as F
import matplotlib.pyplot as plt
import torchvision.transforms as torch_transforms

# %%
################################# Hyperparameters ##############################
M,N = SHAPE = (8,8)
EPOCHS = 75
BATCH_SIZE = 1024
SUBCLASSES = [1,2,3,4]
DATA_SIZE = N*M
LABEL_SIZE = len(SUBCLASSES)
# Stochastic Gradient Descent
learning_rate = 0.1
weight_decay = 1e-4
momentum = 0.5

# %%
#################################### Input Data ################################
train_dataset = qaml.datasets.OptDigits(root='./data/', train=True,
                                     transform=torch_transforms.Compose([
                                     torch_transforms.ToTensor(),
                                     lambda x:(x>0.5).to(x.dtype)]), #Binarize
                                     target_transform=torch_transforms.Compose([
                                     lambda x:torch.LongTensor([x.astype(int)]),
                                     lambda x:F.one_hot(x-1,len(SUBCLASSES))]),
                                     download=True)

train_idx = [i for i,y in enumerate(train_dataset.targets) if y in SUBCLASSES]
sampler = torch.utils.data.SubsetRandomSampler(train_idx)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE,
                                           sampler=sampler)

fig,axs = plt.subplots(4,5)
subdataset = zip(train_dataset.data[train_idx],train_dataset.targets[train_idx])
for ax,(img,label) in zip(axs.flat,subdataset):
    ax.matshow(img>0.5)
    ax.set_title(int(label))
    ax.axis('off')
plt.tight_layout()

test_dataset = qaml.datasets.OptDigits(root='./data/', train=False,
                                    transform=torch_transforms.Compose([
                                    torch_transforms.ToTensor(),
                                    lambda x:(x>0.5).to(x.dtype)]), #Binarize
                                    target_transform=torch_transforms.Compose([
                                    lambda x:torch.LongTensor([x.astype(int)]),
                                    lambda x:F.one_hot(x-1,len(SUBCLASSES))]),
                                    download=True)

test_idx = [i for i,y in enumerate(test_dataset.targets) if y in SUBCLASSES]
sampler = torch.utils.data.SubsetRandomSampler(test_idx)
test_loader = torch.utils.data.DataLoader(test_dataset,sampler=sampler)
# Out:
# Using downloaded and verified file ./data/OptDigits\raw\optdigits.tra
# Using downloaded and verified file ./data/OptDigits\raw\optdigits.tes

# %%
################################# Model Definition #############################
VISIBLE_SIZE = DATA_SIZE + LABEL_SIZE
HIDDEN_SIZE = 16

# Specify model with dimensions
rbm = qaml.nn.RBM(VISIBLE_SIZE,HIDDEN_SIZE)

# Set up optimizer
optimizer = torch.optim.SGD(rbm.parameters(),
                            lr=learning_rate,
                            weight_decay=weight_decay,
                            momentum=momentum)

# Set up training mechanisms
gibbs_sampler = qaml.sampler.GibbsNetworkSampler(rbm)
CD = qaml.autograd.SampleBasedConstrastiveDivergence()

# %%
################################## Model Training ##############################
# Set the model to training mode
rbm.train()
err_log = []
accuracy_log = []
b_log = [rbm.b.detach().clone().numpy()]
c_log = [rbm.c.detach().clone().numpy()]
W_log = [rbm.W.detach().clone().numpy().flatten()]
for t in range(EPOCHS):
    epoch_error = torch.Tensor([0.])
    for img_batch, labels_batch in train_loader:
        input_data = torch.cat((img_batch.flatten(1),labels_batch.flatten(1)),1)

        # Positive Phase
        v0, prob_h0 = input_data, rbm(input_data)
        # Negative Phase
        vk, prob_hk = gibbs_sampler(v0,k=1)

        # Reconstruction error from Contrastive Divergence
        err = CD.apply((v0,prob_h0), (vk,prob_hk), *rbm.parameters())

        # Do not accumulated gradients
        optimizer.zero_grad()

        # Compute gradients
        err.backward()

        # Update parameters
        optimizer.step()
        epoch_error  += err

    # Error Log
    b_log.append(rbm.b.detach().clone().numpy())
    c_log.append(rbm.c.detach().clone().numpy())
    W_log.append(rbm.W.detach().clone().numpy().flatten())
    err_log.append(epoch_error.item())
    print(f"Epoch {t} Reconstruction Error = {epoch_error.item()}")

    ############################## CLASSIFICATION ##################################
    count = 0
    for i,(test_data, test_label) in enumerate(test_loader,start=10):
        prob_hk = rbm(torch.cat((test_data.flatten(1),torch.zeros(1,LABEL_SIZE)),dim=1))
        _,label_pred = rbm.generate(prob_hk).split((DATA_SIZE,LABEL_SIZE),dim=1)
        if label_pred.argmax() == test_label.argmax():
            count+=1
    accuracy_log.append(count/len(test_idx))
    print(f"Testing accuracy: {count}/{len(test_idx)} ({count/len(test_idx):.2f})")
# Out:
# Epoch 0 Reconstruction Error = 46.99585723876953
# Testing accuracy: 258/723 (0.36)
# Epoch 1 Reconstruction Error = 28.082111358642578
# Testing accuracy: 357/723 (0.49)
# Epoch 2 Reconstruction Error = 17.244247436523438
# Testing accuracy: 359/723 (0.50)
# Epoch 3 Reconstruction Error = 11.732135772705078
# Testing accuracy: 321/723 (0.44)
# Epoch 4 Reconstruction Error = 8.026470184326172
# Testing accuracy: 345/723 (0.48)
# Epoch 5 Reconstruction Error = 5.885930061340332
# Testing accuracy: 373/723 (0.52)
# Epoch 6 Reconstruction Error = 4.941016674041748
# Testing accuracy: 389/723 (0.54)
# Epoch 7 Reconstruction Error = 4.741575241088867
# Testing accuracy: 431/723 (0.60)
# Epoch 8 Reconstruction Error = 3.7258572578430176
# Testing accuracy: 478/723 (0.66)
# Epoch 9 Reconstruction Error = 3.4312057495117188
# Testing accuracy: 492/723 (0.68)
# Epoch 10 Reconstruction Error = 3.1120452880859375
# Testing accuracy: 508/723 (0.70)
# Epoch 11 Reconstruction Error = 3.0052175521850586
# Testing accuracy: 534/723 (0.74)
# Epoch 12 Reconstruction Error = 2.683866500854492
# Testing accuracy: 550/723 (0.76)
# Epoch 13 Reconstruction Error = 2.6189794540405273
# Testing accuracy: 555/723 (0.77)
# Epoch 14 Reconstruction Error = 2.4903736114501953
# Testing accuracy: 569/723 (0.79)
# Epoch 15 Reconstruction Error = 2.3064703941345215
# Testing accuracy: 583/723 (0.81)
# Epoch 16 Reconstruction Error = 2.3627500534057617
# Testing accuracy: 585/723 (0.81)
# Epoch 17 Reconstruction Error = 1.8897221088409424
# Testing accuracy: 580/723 (0.80)
# Epoch 18 Reconstruction Error = 1.8349804878234863
# Testing accuracy: 583/723 (0.81)
# Epoch 19 Reconstruction Error = 1.8611639738082886
# Testing accuracy: 588/723 (0.81)
# Epoch 20 Reconstruction Error = 1.9219751358032227
# Testing accuracy: 585/723 (0.81)
# Epoch 21 Reconstruction Error = 1.5973763465881348
# Testing accuracy: 585/723 (0.81)
# Epoch 22 Reconstruction Error = 1.7064741849899292
# Testing accuracy: 611/723 (0.85)
# Epoch 23 Reconstruction Error = 1.6857191324234009
# Testing accuracy: 620/723 (0.86)
# Epoch 24 Reconstruction Error = 1.6244723796844482
# Testing accuracy: 629/723 (0.87)
# Epoch 25 Reconstruction Error = 1.818960189819336
# Testing accuracy: 636/723 (0.88)
# Epoch 26 Reconstruction Error = 1.6600596904754639
# Testing accuracy: 635/723 (0.88)
# Epoch 27 Reconstruction Error = 1.721548080444336
# Testing accuracy: 640/723 (0.89)
# Epoch 28 Reconstruction Error = 1.6336164474487305
# Testing accuracy: 640/723 (0.89)
# Epoch 29 Reconstruction Error = 1.652941107749939
# Testing accuracy: 641/723 (0.89)
# Epoch 30 Reconstruction Error = 1.4628357887268066
# Testing accuracy: 640/723 (0.89)
# Epoch 31 Reconstruction Error = 1.498723030090332
# Testing accuracy: 641/723 (0.89)
# Epoch 32 Reconstruction Error = 1.4975500106811523
# Testing accuracy: 644/723 (0.89)
# Epoch 33 Reconstruction Error = 1.4535222053527832
# Testing accuracy: 645/723 (0.89)
# Epoch 34 Reconstruction Error = 1.3965997695922852
# Testing accuracy: 645/723 (0.89)
# Epoch 35 Reconstruction Error = 1.512542486190796
# Testing accuracy: 644/723 (0.89)
# Epoch 36 Reconstruction Error = 1.3407877683639526
# Testing accuracy: 646/723 (0.89)
# Epoch 37 Reconstruction Error = 1.4277269840240479
# Testing accuracy: 650/723 (0.90)
# Epoch 38 Reconstruction Error = 1.3433891534805298
# Testing accuracy: 650/723 (0.90)
# Epoch 39 Reconstruction Error = 1.4394614696502686
# Testing accuracy: 650/723 (0.90)
# Epoch 40 Reconstruction Error = 1.2755141258239746
# Testing accuracy: 650/723 (0.90)
# Epoch 41 Reconstruction Error = 1.255444049835205
# Testing accuracy: 650/723 (0.90)
# Epoch 42 Reconstruction Error = 1.2406339645385742
# Testing accuracy: 650/723 (0.90)
# Epoch 43 Reconstruction Error = 1.2824227809906006
# Testing accuracy: 650/723 (0.90)
# Epoch 44 Reconstruction Error = 1.2108681201934814
# Testing accuracy: 649/723 (0.90)
# Epoch 45 Reconstruction Error = 1.265287160873413
# Testing accuracy: 653/723 (0.90)
# Epoch 46 Reconstruction Error = 1.428308129310608
# Testing accuracy: 654/723 (0.90)
# Epoch 47 Reconstruction Error = 1.208803415298462
# Testing accuracy: 654/723 (0.90)
# Epoch 48 Reconstruction Error = 1.3729645013809204
# Testing accuracy: 654/723 (0.90)
# Epoch 49 Reconstruction Error = 1.1701383590698242
# Testing accuracy: 654/723 (0.90)
# Epoch 50 Reconstruction Error = 1.216156244277954
# Testing accuracy: 655/723 (0.91)
# Epoch 51 Reconstruction Error = 1.111872911453247
# Testing accuracy: 656/723 (0.91)
# Epoch 52 Reconstruction Error = 1.2824313640594482
# Testing accuracy: 656/723 (0.91)
# Epoch 53 Reconstruction Error = 1.2729721069335938
# Testing accuracy: 658/723 (0.91)
# Epoch 54 Reconstruction Error = 1.3230061531066895
# Testing accuracy: 658/723 (0.91)
# Epoch 55 Reconstruction Error = 1.1888861656188965
# Testing accuracy: 658/723 (0.91)
# Epoch 56 Reconstruction Error = 1.059034824371338
# Testing accuracy: 657/723 (0.91)
# Epoch 57 Reconstruction Error = 1.201608657836914
# Testing accuracy: 655/723 (0.91)
# Epoch 58 Reconstruction Error = 1.1803081035614014
# Testing accuracy: 656/723 (0.91)
# Epoch 59 Reconstruction Error = 1.121880292892456
# Testing accuracy: 658/723 (0.91)
# Epoch 60 Reconstruction Error = 1.1028876304626465
# Testing accuracy: 659/723 (0.91)
# Epoch 61 Reconstruction Error = 1.0906996726989746
# Testing accuracy: 660/723 (0.91)
# Epoch 62 Reconstruction Error = 1.1170802116394043
# Testing accuracy: 660/723 (0.91)
# Epoch 63 Reconstruction Error = 1.1878961324691772
# Testing accuracy: 661/723 (0.91)
# Epoch 64 Reconstruction Error = 1.2295522689819336
# Testing accuracy: 660/723 (0.91)
# Epoch 65 Reconstruction Error = 1.0272775888442993
# Testing accuracy: 661/723 (0.91)
# Epoch 66 Reconstruction Error = 1.068816065788269
# Testing accuracy: 662/723 (0.92)
# Epoch 67 Reconstruction Error = 0.8811555504798889
# Testing accuracy: 661/723 (0.91)
# Epoch 68 Reconstruction Error = 1.0769736766815186
# Testing accuracy: 662/723 (0.92)
# Epoch 69 Reconstruction Error = 1.1253511905670166
# Testing accuracy: 662/723 (0.92)
# Epoch 70 Reconstruction Error = 1.1182897090911865
# Testing accuracy: 661/723 (0.91)
# Epoch 71 Reconstruction Error = 1.0345466136932373
# Testing accuracy: 663/723 (0.92)
# Epoch 72 Reconstruction Error = 1.1070424318313599
# Testing accuracy: 663/723 (0.92)
# Epoch 73 Reconstruction Error = 1.086987018585205
# Testing accuracy: 665/723 (0.92)
# Epoch 74 Reconstruction Error = 0.98683762550354
# Testing accuracy: 665/723 (0.92)

# %%
############################ MODEL VISUALIZATION ###############################

# Testing accuracy graph
fig, ax = plt.subplots()
ax.plot(accuracy_log)
plt.ylabel("Testing Accuracy")
plt.xlabel("Epoch")
plt.savefig("classical_accuracy.pdf")

# L1 error graph
fig, ax = plt.subplots()
ax.plot(err_log)
plt.ylabel("Reconstruction Error")
plt.xlabel("Epoch")
plt.savefig("classical_err_log.pdf")

# Visible bias graph
fig, ax = plt.subplots()
ax.set_prop_cycle('color', list(plt.get_cmap('turbo',DATA_SIZE).colors))
lc_v = ax.plot(b_log)
plt.legend(iter(lc_v),[f'b{i}' for i in range(DATA_SIZE)],ncol=2,bbox_to_anchor=(1,1))
plt.ylabel("Visible Biases")
plt.xlabel("Epoch")
plt.savefig("classical_visible_bias_log.pdf")

# Hidden bias graph
fig, ax = plt.subplots()
ax.set_prop_cycle('color', list(plt.get_cmap('turbo',HIDDEN_SIZE).colors))
lc_h = plt.plot(c_log)
plt.legend(lc_h,[f'c{i}' for i in range(HIDDEN_SIZE)],ncol=2,bbox_to_anchor=(1,1))
plt.ylabel("Hidden Biases")
plt.xlabel("Epoch")
plt.savefig("classical_hidden_bias_log.pdf")

# Weights graph
fig, ax = plt.subplots()
ax.set_prop_cycle('color', list(plt.get_cmap('turbo',HIDDEN_SIZE*DATA_SIZE).colors))
lc_w = plt.plot(W_log)
plt.ylabel("Weights")
plt.xlabel("Epoch")
plt.savefig("classical_weights_log.pdf")

# %%
################################## VISUALIZE ###################################
plt.matshow(rbm.b.detach()[:DATA_SIZE].view(*SHAPE), cmap='viridis', vmin=-1, vmax=1)
plt.colorbar()

fig,axs = plt.subplots(HIDDEN_SIZE//4,4)
for i,ax in enumerate(axs.flat):
    weight_matrix = rbm.W[i].detach()[:DATA_SIZE].view(*SHAPE)
    ms = ax.matshow(weight_matrix, cmap='viridis', vmin=-1, vmax=1)
    ax.axis('off')
cbar = fig.colorbar(ms, ax=axs.ravel().tolist(), shrink=0.95)
plt.savefig("classical_weights.png")
